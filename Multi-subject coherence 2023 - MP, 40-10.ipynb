# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline

# %%
import utils # stuff I've written for this project

import os, sys, datetime, glob, re
import os.path as op

import fnmatch

import logging
logger = logging.getLogger('utils') # this logger is set up and defined in utils.py

import numpy as np
np.set_printoptions(precision=4)
import pandas as pd
import matplotlib.pyplot as plt
import shutil

import seaborn as sns

import statsmodels.api as sm
from statsmodels.formula.api import ols

import scipy.stats as st

import warnings
# Out:
# 2023-03-06 23:29:33,739 - utils - DEBUG - <Logger utils (DEBUG)>
# /home/smerdis/anaconda3/envs/sns12/lib/python3.10/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %%
sep = '\n'

#files = glob.glob("sub-*_coh_df_alllgn_allcortical*.csv")
#files = glob.glob("sub-*_coh_df_picklgn_allcortical.csv")
#files = glob.glob("sub-*_coh_df_finallgn_allcortical_conn*.csv")
#files = glob.glob("sub-*_coh_df_revisedlgn_allcortical_conn*_thresholded.csv")
files = glob.glob("sub-*_coh_df_revisedlgn_allcortical_conn*_volconstraint_meantarget.csv")


files.sort()

#files_reduced = [f for f in files if 'sub-ZG' not in f]
#files_manual = [f for f in files if 'withmanual' in f]

files_final = files #files_manual #files_reduced

logger.debug(f"\nFound:\n{sep.join(files)}.\nWill only analyze:\n{sep.join(files_final)}")
# Out:
# 2023-03-06 23:29:34,515 - utils - DEBUG -
# Found:
# sub-BC_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-BC_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-CF_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-CF_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-LL_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-LL_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-SR_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-SR_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-ZG_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-ZG_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv.
# Will only analyze:
# sub-BC_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-BC_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-CF_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-CF_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-LL_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-LL_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-SR_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-SR_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv
# sub-ZG_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv
# sub-ZG_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv

# %%
sub_dfs = {}
for i, file in enumerate(files_final):
    parts = file.split('_')
    if parts[0][:3] == 'sub':
        key = parts[0]
    else:
        raise Error("Coherence data files must begin with 'sub-<sub_code>'")
    df = pd.read_csv(file)
    if key in sub_dfs:
        df['session'] = 2
        concat_df = pd.concat([sub_dfs[key], df])
        sub_dfs[key] = concat_df
        assert(sub_dfs[key].session.nunique() == 2)
    else:
        df['session'] = 1
        sub_dfs[key] = df
        assert(sub_dfs[key].session.nunique() == 1)

    print(file, key, len(sub_dfs[key]))
# Out:
# sub-BC_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv sub-BC 792
# sub-BC_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv sub-BC 1584
# sub-CF_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv sub-CF 396
# sub-CF_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv sub-CF 792
# sub-LL_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv sub-LL 792
# sub-LL_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv sub-LL 1320
# sub-SR_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv sub-SR 612
# sub-SR_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv sub-SR 1224
# sub-ZG_coh_df_revisedlgn_allcortical_conn1_volconstraint_meantarget.csv sub-ZG 384
# sub-ZG_coh_df_revisedlgn_allcortical_conn2_volconstraint_meantarget.csv sub-ZG 960

# %%
df = pd.concat(sub_dfs).reset_index().drop(['level_1', 'Unnamed: 0'], axis=1).rename(columns={'level_0':'subj'})
df.head()
# Out:
#      subj            seed   target measurement     value     run condition  \
# 0  sub-BC  LLGNrevisedM90  LDORSAL   coherence  0.375980  run-01     leftM
# 1  sub-BC  LLGNrevisedM90  LDORSAL   coherence  0.365690  run-02     leftP
# 2  sub-BC  LLGNrevisedM90  LDORSAL   coherence  0.479232  run-03    rightM
# 3  sub-BC  LLGNrevisedM90  LDORSAL   coherence  0.444461  run-04    rightP
# 4  sub-BC  LLGNrevisedM90  LDORSAL   coherence  0.302263  run-05     leftM
#
#                                                 bold  session
# 0  /home/smerdis/data/LGN/BIDS/BC_combined/deriva...        1
# 1  /home/smerdis/data/LGN/BIDS/BC_combined/deriva...        1
# 2  /home/smerdis/data/LGN/BIDS/BC_combined/deriva...        1
# 3  /home/smerdis/data/LGN/BIDS/BC_combined/deriva...        1
# 4  /home/smerdis/data/LGN/BIDS/BC_combined/deriva...        1

# %%
# Change V3ABC region to V3AB per MAS feedback on paper draft ~Thanksgiving 2022
df.loc[df.target=='RV3ABC', 'target'] = 'RV3AB'
df.loc[df.target=='LV3ABC', 'target'] = 'LV3AB'

# Change V4C region to V4
df.loc[df.target=='RV4C', 'target'] = 'RV4'
df.loc[df.target=='LV4C', 'target'] = 'LV4'

# %% [markdown]
# ### Add columns that will be useful later

# %%
df.seed.unique()
# Out:
# array(['LLGNrevisedM90', 'LLGNrevisedP40', 'RLGNrevisedM90',
#        'RLGNrevisedP40', 'LLGNrevisedUnion', 'RLGNrevisedUnion'],
#       dtype=object)

# %%
df = df.loc[~df.seed.str.contains('80'), :]

# %%
[s.split('LGN') for s in df.seed.unique()]
# Out:
# [['L', 'revisedM90'],
#  ['L', 'revisedP40'],
#  ['R', 'revisedM90'],
#  ['R', 'revisedP40'],
#  ['L', 'revisedUnion'],
#  ['R', 'revisedUnion']]

# %%
def decide_seed_mp(row):
    # row comes in as a Series, decide if it's M or P
    slug = row['seed'].split('LGN')[-1]
    if not slug: # slug evaluates to False, aka it's empty, so name is 'LLGN' or anything with nothing after 'LGN'
        seed_mp = None
    else:
        if 'M' in slug:
            seed_mp = 'M'
        elif 'P' in slug:
            seed_mp = 'P'
        else:
            seed_mp = None
    #print(row['seed'], slug, seed_mp)
    return seed_mp

# %%
df['seed_hem'] = df.apply(lambda row: row['seed'][0], axis=1) # e.g. LLGNM80 => 'L'
df['seed_region'] = df.apply(lambda row: row['seed'][1:], axis=1) # e.g. LLGNM80 => LGNM80
df['target_hem'] = df.apply(lambda row: row['target'][0], axis=1) # e.g. LV1 => 'L'
df['target_region'] = df.apply(lambda row: row['target'][1:], axis=1) # e.g. LV1 => V1
#df['seed_mp'] = df.apply(lambda row: row['seed'].split('LGN')[-1][0] if row['seed'].split('LGN')[-1] else None, axis=1) # e.g. LLGNM80 => 'M', assumes seed contains 'LGN'
df['seed_mp'] = df.apply(decide_seed_mp, axis=1) # e.g. LLGNM80 => 'M', assumes seed contains 'LGN'
df['stim_type'] = df.apply(lambda row: row['condition'][-1], axis=1) # e.g. 'leftM' => 'M'
df['attend_hem'] = df.apply(lambda row: row['condition'][0].upper(), axis=1) # e.g. 'leftM' => 'L'

# %%
# Check that there are only as many unique values as we expect (L/R, M/P)
#assert(df['seed_hem'].nunique() == 2)
assert(df['target_hem'].nunique() == 2)
assert(df['seed_mp'].nunique() == 2) # but there may be Nones, e.g. for LLGN as a whole (not M/P)
assert(df['stim_type'].nunique() == 2)
assert(df['attend_hem'].nunique() == 2)

# %%
df.seed_mp.unique()
# Out:
# array(['M', 'P', None], dtype=object)

# %%
df.seed_region.unique()
# Out:
# array(['LGNrevisedM90', 'LGNrevisedP40', 'LGNrevisedUnion'], dtype=object)

# %%
# Are the seed and target in same hemisphere?
df['ipsi_seedtarget'] = df.apply(lambda row: row['seed_hem'] == row['target_hem'], axis=1)
df['ipsi_seedtarget'].value_counts()
# Out:
# True    5880
# Name: ipsi_seedtarget, dtype: int64

# %%
# Is the stimulation type the same as the seed region for this row?
df['seed_stim'] = df.apply(lambda row: row['seed_mp'] == row['stim_type'], axis=1)
df['seed_stim'].value_counts()
# Out:
# False    3920
# True     1960
# Name: seed_stim, dtype: int64

# %% [markdown]
# ### Identify grouping variables

# %%
constructed_cols = ['seed_hem','seed_region','target_hem','target_region','seed_mp','stim_type',
                    'attend_hem','ipsi_seedtarget','seed_stim']
id_cols = ['subj','seed','target','measurement','condition']
gvars_sub = [*id_cols, *constructed_cols]

# %%
df['target_region'].unique()
# Out:
# array(['DORSAL', 'IPS', 'LO', 'TO', 'v1', 'V2', 'V3', 'V3AB', 'V4',
#        'VENTRAL', 'VO'], dtype=object)

# %% [markdown]
# ### Group target ROIs

# %%
df.groupby('subj')['target_region'].unique()
# Out:
# subj
# sub-BC    [DORSAL, IPS, LO, TO, v1, V2, V3, V3AB, V4, VE...
# sub-CF                      [DORSAL, IPS, v1, V2, V3, V3AB]
# sub-LL    [DORSAL, IPS, LO, TO, v1, V2, V3, V3AB, V4, VE...
# sub-SR     [DORSAL, IPS, LO, TO, v1, V2, V3, V3AB, VENTRAL]
# sub-ZG         [DORSAL, IPS, LO, v1, V2, V3, V3AB, VENTRAL]
# Name: target_region, dtype: object

# %%
targets = df.target.unique()
# early_vis_rois = [f for f in targets if fnmatch.fnmatch(f, '*[LR]v[12]*')]
# v3s = [f for f in targets if fnmatch.fnmatch(f, '*[LR]v3[dab]*')]
# v3vs = [f for f in targets if fnmatch.fnmatch(f, '*[LR]v3v*')]
# ips = [f for f in targets if fnmatch.fnmatch(f, '*[LR]ips*')]
# dorsal = v3s + ips
# v4s = [f for f in targets if fnmatch.fnmatch(f, '*[LR]v4*')]
# ventral = v3vs + v4s + [f for f in targets if fnmatch.fnmatch(f, '*[LR][vtl]o*')]
print(targets, len(targets)) #, early_vis_rois, len(early_vis_rois), 
      #dorsal, len(dorsal), ventral, len(ventral), sep="\n")
# Out:
# ['LDORSAL' 'LIPS' 'LLO' 'LTO' 'Lv1' 'LV2' 'LV3' 'LV3AB' 'LV4' 'LVENTRAL'
#  'LVO' 'RDORSAL' 'RIPS' 'RLO' 'RTO' 'Rv1' 'RV2' 'RV3' 'RV3AB' 'RV4'
#  'RVENTRAL' 'RVO'] 22

# %%
target_regions = df.target_region.unique()
print(target_regions, len(target_regions))
# define the target regions we wish to plot and the order they are to be plotted in
target_regions_ordered = ['v1', 'V2', 'V3', 'V3AB', 'IPS', 'TO', 'V4', 'VO', 'LO', 'DORSAL', 'VENTRAL',                      
'v2d', 'v2v', 'v3d', 'v3v', 'v4',
 'ips0', 'ips1', 'ips2', 'ips3', 'ips4', 'ips5',
'lo1', 'lo2', 'to1', 'to2',  'vo1', 'vo2']
print(target_regions_ordered, len(target_regions_ordered))
df['target_region'] = pd.Categorical(df.target_region, categories=target_regions_ordered, ordered=True)
# Out:
# ['DORSAL' 'IPS' 'LO' 'TO' 'v1' 'V2' 'V3' 'V3AB' 'V4' 'VENTRAL' 'VO'] 11
# ['v1', 'V2', 'V3', 'V3AB', 'IPS', 'TO', 'V4', 'VO', 'LO', 'DORSAL', 'VENTRAL', 'v2d', 'v2v', 'v3d', 'v3v', 'v4', 'ips0', 'ips1', 'ips2', 'ips3', 'ips4', 'ips5', 'lo1', 'lo2', 'to1', 'to2', 'vo1', 'vo2'] 28

# %%
display_regions = ['v1', 'V2', 'V3', 'V3AB', 'IPS', 'LO', 'V4', 'TO', 'VO', 'DORSAL', 'VENTRAL']

# %%
df = df.sort_values(by=['subj', 'seed', 'target_region', 'target'])
df[df.subj=='sub-ZG']
# Out:
#         subj              seed    target measurement     value     run  \
# 4944  sub-ZG    LLGNrevisedM90       Lv1   coherence  0.300447  run-01
# 4945  sub-ZG    LLGNrevisedM90       Lv1   coherence  0.511391  run-02
# 4946  sub-ZG    LLGNrevisedM90       Lv1   coherence  0.523915  run-03
# 4947  sub-ZG    LLGNrevisedM90       Lv1   coherence  0.459718  run-04
# 4948  sub-ZG    LLGNrevisedM90       Lv1   coherence  0.516911  run-05
# ...      ...               ...       ...         ...       ...     ...
# 5875  sub-ZG  RLGNrevisedUnion  RVENTRAL   coherence  0.574398  run-08
# 5876  sub-ZG  RLGNrevisedUnion  RVENTRAL   coherence  0.467477  run-09
# 5877  sub-ZG  RLGNrevisedUnion  RVENTRAL   coherence  0.364631  run-10
# 5878  sub-ZG  RLGNrevisedUnion  RVENTRAL   coherence  0.321276  run-11
# 5879  sub-ZG  RLGNrevisedUnion  RVENTRAL   coherence  0.417463  run-12
#
#      condition                                               bold  session  \
# 4944     leftM  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        1
# 4945     leftP  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        1
# 4946    rightM  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        1
# 4947    rightP  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        1
# 4948     leftM  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        1
# ...        ...                                                ...      ...
# 5875    rightP  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        2
# 5876     leftM  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        2
# 5877     leftP  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        2
# 5878    rightM  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        2
# 5879    rightP  /home/smerdis/data/LGN/BIDS/ZG_combined/deriva...        2
#
#      seed_hem      seed_region target_hem target_region seed_mp stim_type  \
# 4944        L    LGNrevisedM90          L            v1       M         M
# 4945        L    LGNrevisedM90          L            v1       M         P
# 4946        L    LGNrevisedM90          L            v1       M         M
# 4947        L    LGNrevisedM90          L            v1       M         P
# 4948        L    LGNrevisedM90          L            v1       M         M
# ...       ...              ...        ...           ...     ...       ...
# 5875        R  LGNrevisedUnion          R       VENTRAL    None         P
# 5876        R  LGNrevisedUnion          R       VENTRAL    None         M
# 5877        R  LGNrevisedUnion          R       VENTRAL    None         P
# 5878        R  LGNrevisedUnion          R       VENTRAL    None         M
# 5879        R  LGNrevisedUnion          R       VENTRAL    None         P
#
#      attend_hem  ipsi_seedtarget  seed_stim
# 4944          L             True       True
# 4945          L             True      False
# 4946          R             True       True
# 4947          R             True      False
# 4948          L             True       True
# ...         ...              ...        ...
# 5875          R             True      False
# 5876          L             True      False
# 5877          L             True      False
# 5878          R             True      False
# 5879          R             True      False
#
# [960 rows x 18 columns]

# %%
df_ipsi = df[df['ipsi_seedtarget']] # only ipsilateral seed-target pairs
print(len(df_ipsi))
df_biglgn = df[df['seed_mp'].isna()] # only whole LGN seed regions, not M/P subregions
print(len(df_biglgn))
df_ipsi_biglgn = df_ipsi[df_ipsi['seed_mp'].isna()] # only whole-lgn seeds with ipsilateral cortical targets
print(df_ipsi_biglgn['seed'].unique())
df_ipsi_sublgn = df_ipsi[~df_ipsi['seed_mp'].isna()] # only sub-lgn (M/P) seeds with ipsilateral cortical targets
print(df_ipsi_sublgn['seed_region'].unique())
print(len(df_ipsi_sublgn))
# Out:
# 5880
# 1960
# ['LLGNrevisedUnion' 'RLGNrevisedUnion']
# ['LGNrevisedM90' 'LGNrevisedP40']
# 3920

# %% [markdown]
# ## Analysis via collapsing across various things

# %% [markdown]
# ### Graphs

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    sns.catplot(data=df_ipsi_biglgn, kind='strip', x='target_region', y='value', row='subj', hue='seed', col='seed_hem',
            sharex=False, legend=True, order=display_regions).set_axis_labels('Target', "Coherence") \
            .fig.suptitle("Whole LGN coherence with ipsilateral cortical targets", y=1.03)

# %%
df_ipsi_biglgn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1960 entries, 576 to 5879
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subj             1960 non-null   object
#  1   seed             1960 non-null   object
#  2   target           1960 non-null   object
#  3   measurement      1960 non-null   object
#  4   value            1960 non-null   float64
#  5   run              1960 non-null   object
#  6   condition        1960 non-null   object
#  7   bold             1960 non-null   object
#  8   session          1960 non-null   int64
#  9   seed_hem         1960 non-null   object
#  10  seed_region      1960 non-null   object
#  11  target_hem       1960 non-null   object
#  12  target_region    1960 non-null   category
#  13  seed_mp          0 non-null      object
#  14  stim_type        1960 non-null   object
#  15  attend_hem       1960 non-null   object
#  16  ipsi_seedtarget  1960 non-null   bool
#  17  seed_stim        1960 non-null   bool
# dtypes: bool(2), category(1), float64(1), int64(1), object(13)
# memory usage: 316.5+ KB

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    ylim= (0.2, 0.6)
    for gv, g in df_ipsi_biglgn.groupby(['subj', 'seed_region']):
        sns.catplot(data=g.reset_index(), kind='strip', x='target_region', y='value', row='session',
                    col='condition', hue='run', legend=True, order=display_regions) \
        .set(ylim=ylim)\
        .set_axis_labels('Target', "Coherence") \
        .fig.suptitle(f"{gv} Whole LGN coherence with ipsilateral cortical targets", y=1.03)

# %%
gvars_sub_ses = gvars_sub + ['session']
print(gvars_sub_ses)
# Out:
# ['subj', 'seed', 'target', 'measurement', 'condition', 'seed_hem', 'seed_region', 'target_hem', 'target_region', 'seed_mp', 'stim_type', 'attend_hem', 'ipsi_seedtarget', 'seed_stim', 'session']

# %%
mean_groups = df_ipsi_sublgn.groupby(gvars_sub_ses, observed=True)
print(len(mean_groups))
#for gv, g in mean_groups:
#    print(gv, len(g), np.mean(g['value']), sep='\n')
# Out:
# 1408

# %%
df_meanrun = mean_groups['value'].agg(['mean','sem'])
# next line renames the columns returned by agg() only since we haven't reset the index yet
df_meanrun.columns = df_meanrun.columns.map(lambda x: f"value_{x}")
df_meanrun = df_meanrun.reset_index()
df_meanrun.head()
# Out:
#      subj            seed   target measurement condition seed_hem  \
# 0  sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 1  sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 2  sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 3  sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 4  sub-BC  LLGNrevisedM90  LDORSAL   coherence    rightM        L
#
#      seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 0  LGNrevisedM90          L        DORSAL       M         M          L
# 1  LGNrevisedM90          L        DORSAL       M         M          L
# 2  LGNrevisedM90          L        DORSAL       M         P          L
# 3  LGNrevisedM90          L        DORSAL       M         P          L
# 4  LGNrevisedM90          L        DORSAL       M         M          R
#
#    ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 0             True       True        1    0.353614   0.025746
# 1             True       True        2    0.355229   0.027374
# 2             True      False        1    0.290234   0.049488
# 3             True      False        2    0.329836   0.012863
# 4             True       True        1    0.410930   0.059675

# %%
display_order = [v for v in df_meanrun.target_region.cat.categories if v in display_regions]

# %%
df_meanrun_xatt = df_meanrun.groupby(['subj', 'seed', 'target', 'measurement', 'seed_hem', 'seed_region', 
    'target_hem','target_region','seed_mp', 'stim_type', 'ipsi_seedtarget'], observed=True)['value_mean']\
.agg(['mean', 'sem']).reset_index()

# %%
df_meanrun_xatt
# Out:
#        subj            seed    target measurement seed_hem    seed_region  \
# 0    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 1    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 2    sub-BC  LLGNrevisedM90      LIPS   coherence        L  LGNrevisedM90
# 3    sub-BC  LLGNrevisedM90      LIPS   coherence        L  LGNrevisedM90
# 4    sub-BC  LLGNrevisedM90       LLO   coherence        L  LGNrevisedM90
# ..      ...             ...       ...         ...      ...            ...
# 347  sub-ZG  RLGNrevisedP40     RV3AB   coherence        R  LGNrevisedP40
# 348  sub-ZG  RLGNrevisedP40  RVENTRAL   coherence        R  LGNrevisedP40
# 349  sub-ZG  RLGNrevisedP40  RVENTRAL   coherence        R  LGNrevisedP40
# 350  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
# 351  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
#
#     target_hem target_region seed_mp stim_type  ipsi_seedtarget      mean  \
# 0            L        DORSAL       M         M             True  0.395829
# 1            L        DORSAL       M         P             True  0.358835
# 2            L           IPS       M         M             True  0.391815
# 3            L           IPS       M         P             True  0.355452
# 4            L            LO       M         M             True  0.351304
# ..         ...           ...     ...       ...              ...       ...
# 347          R          V3AB       P         P             True  0.389503
# 348          R       VENTRAL       P         M             True  0.395480
# 349          R       VENTRAL       P         P             True  0.397165
# 350          R            v1       P         M             True  0.433396
# 351          R            v1       P         P             True  0.415582
#
#           sem
# 0    0.026210
# 1    0.029582
# 2    0.025247
# 3    0.031266
# 4    0.017844
# ..        ...
# 347  0.025402
# 348  0.022572
# 349  0.022441
# 350  0.025758
# 351  0.021443
#
# [352 rows x 13 columns]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for gv, g in df_meanrun_xatt.groupby(['subj']):
        sns.catplot(data=g.reset_index(), kind='strip', x='target_region', y='mean', col='seed_mp',
                    row='target_hem', hue='stim_type', sharex=False, legend=True, ci=None, dodge=True,
                    order=display_order) \
        .set_axis_labels('Target', "Coherence") \
        .fig.suptitle(f"{gv} LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for gv, g in df_meanrun.groupby(['subj']):
        print(g)
        sns.catplot(data=g.reset_index(), kind='strip', x='target_region', y='value_mean', row='seed_mp',
                    col='stim_type', hue='session', sharex=False, legend=True, ci=None, dodge=True,
                    order=display_order) \
        .set_axis_labels('Target', "Coherence") \
        .fig.suptitle(f"{gv} LGN subregion coherence with ipsilateral cortical targets", y=1.03)
# Out:
#        subj            seed   target measurement condition seed_hem  \
# 0    sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 1    sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 2    sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 3    sub-BC  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 4    sub-BC  LLGNrevisedM90  LDORSAL   coherence    rightM        L
# ..      ...             ...      ...         ...       ...      ...
# 347  sub-BC  RLGNrevisedP40      Rv1   coherence     leftP        R
# 348  sub-BC  RLGNrevisedP40      Rv1   coherence    rightM        R
# 349  sub-BC  RLGNrevisedP40      Rv1   coherence    rightM        R
# 350  sub-BC  RLGNrevisedP40      Rv1   coherence    rightP        R
# 351  sub-BC  RLGNrevisedP40      Rv1   coherence    rightP        R
#
#        seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 0    LGNrevisedM90          L        DORSAL       M         M          L
# 1    LGNrevisedM90          L        DORSAL       M         M          L
# 2    LGNrevisedM90          L        DORSAL       M         P          L
# 3    LGNrevisedM90          L        DORSAL       M         P          L
# 4    LGNrevisedM90          L        DORSAL       M         M          R
# ..             ...        ...           ...     ...       ...        ...
# 347  LGNrevisedP40          R            v1       P         P          L
# 348  LGNrevisedP40          R            v1       P         M          R
# 349  LGNrevisedP40          R            v1       P         M          R
# 350  LGNrevisedP40          R            v1       P         P          R
# 351  LGNrevisedP40          R            v1       P         P          R
#
#      ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 0               True       True        1    0.353614   0.025746
# 1               True       True        2    0.355229   0.027374
# 2               True      False        1    0.290234   0.049488
# 3               True      False        2    0.329836   0.012863
# 4               True       True        1    0.410930   0.059675
# ..               ...        ...      ...         ...        ...
# 347             True       True        2    0.440609   0.037863
# 348             True      False        1    0.387280   0.030536
# 349             True      False        2    0.371882   0.028138
# 350             True       True        1    0.398110   0.033710
# 351             True       True        2    0.364900   0.025367
#
# [352 rows x 17 columns]
#        subj            seed   target measurement condition seed_hem  \
# 352  sub-CF  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 353  sub-CF  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 354  sub-CF  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 355  sub-CF  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 356  sub-CF  LLGNrevisedM90  LDORSAL   coherence    rightM        L
# ..      ...             ...      ...         ...       ...      ...
# 523  sub-CF  RLGNrevisedP40      Rv1   coherence     leftP        R
# 524  sub-CF  RLGNrevisedP40      Rv1   coherence    rightM        R
# 525  sub-CF  RLGNrevisedP40      Rv1   coherence    rightM        R
# 526  sub-CF  RLGNrevisedP40      Rv1   coherence    rightP        R
# 527  sub-CF  RLGNrevisedP40      Rv1   coherence    rightP        R
#
#        seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 352  LGNrevisedM90          L        DORSAL       M         M          L
# 353  LGNrevisedM90          L        DORSAL       M         M          L
# 354  LGNrevisedM90          L        DORSAL       M         P          L
# 355  LGNrevisedM90          L        DORSAL       M         P          L
# 356  LGNrevisedM90          L        DORSAL       M         M          R
# ..             ...        ...           ...     ...       ...        ...
# 523  LGNrevisedP40          R            v1       P         P          L
# 524  LGNrevisedP40          R            v1       P         M          R
# 525  LGNrevisedP40          R            v1       P         M          R
# 526  LGNrevisedP40          R            v1       P         P          R
# 527  LGNrevisedP40          R            v1       P         P          R
#
#      ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 352             True       True        1    0.481869   0.039304
# 353             True       True        2    0.393333   0.011524
# 354             True      False        1    0.368625   0.035610
# 355             True      False        2    0.372804   0.023250
# 356             True       True        1    0.381719   0.021799
# ..               ...        ...      ...         ...        ...
# 523             True       True        2    0.418304   0.009458
# 524             True      False        1    0.530052   0.033430
# 525             True      False        2    0.384364   0.100980
# 526             True       True        1    0.473195   0.014754
# 527             True       True        2    0.431949   0.015427
#
# [176 rows x 17 columns]
#        subj            seed   target measurement condition seed_hem  \
# 528  sub-LL  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 529  sub-LL  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 530  sub-LL  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 531  sub-LL  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 532  sub-LL  LLGNrevisedM90  LDORSAL   coherence    rightM        L
# ..      ...             ...      ...         ...       ...      ...
# 875  sub-LL  RLGNrevisedP40      Rv1   coherence     leftP        R
# 876  sub-LL  RLGNrevisedP40      Rv1   coherence    rightM        R
# 877  sub-LL  RLGNrevisedP40      Rv1   coherence    rightM        R
# 878  sub-LL  RLGNrevisedP40      Rv1   coherence    rightP        R
# 879  sub-LL  RLGNrevisedP40      Rv1   coherence    rightP        R
#
#        seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 528  LGNrevisedM90          L        DORSAL       M         M          L
# 529  LGNrevisedM90          L        DORSAL       M         M          L
# 530  LGNrevisedM90          L        DORSAL       M         P          L
# 531  LGNrevisedM90          L        DORSAL       M         P          L
# 532  LGNrevisedM90          L        DORSAL       M         M          R
# ..             ...        ...           ...     ...       ...        ...
# 875  LGNrevisedP40          R            v1       P         P          L
# 876  LGNrevisedP40          R            v1       P         M          R
# 877  LGNrevisedP40          R            v1       P         M          R
# 878  LGNrevisedP40          R            v1       P         P          R
# 879  LGNrevisedP40          R            v1       P         P          R
#
#      ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 528             True       True        1    0.425869   0.107095
# 529             True       True        2    0.315635   0.027437
# 530             True      False        1    0.480008   0.053364
# 531             True      False        2    0.321738   0.067930
# 532             True       True        1    0.400164   0.032506
# ..               ...        ...      ...         ...        ...
# 875             True       True        2    0.368249   0.012888
# 876             True      False        1    0.402088   0.026051
# 877             True      False        2    0.380116   0.116219
# 878             True       True        1    0.308085   0.020036
# 879             True       True        2    0.335867   0.039233
#
# [352 rows x 17 columns]
#         subj            seed   target measurement condition seed_hem  \
# 880   sub-SR  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 881   sub-SR  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 882   sub-SR  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 883   sub-SR  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 884   sub-SR  LLGNrevisedM90  LDORSAL   coherence    rightM        L
# ...      ...             ...      ...         ...       ...      ...
# 1147  sub-SR  RLGNrevisedP40      Rv1   coherence     leftP        R
# 1148  sub-SR  RLGNrevisedP40      Rv1   coherence    rightM        R
# 1149  sub-SR  RLGNrevisedP40      Rv1   coherence    rightM        R
# 1150  sub-SR  RLGNrevisedP40      Rv1   coherence    rightP        R
# 1151  sub-SR  RLGNrevisedP40      Rv1   coherence    rightP        R
#
#         seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 880   LGNrevisedM90          L        DORSAL       M         M          L
# 881   LGNrevisedM90          L        DORSAL       M         M          L
# 882   LGNrevisedM90          L        DORSAL       M         P          L
# 883   LGNrevisedM90          L        DORSAL       M         P          L
# 884   LGNrevisedM90          L        DORSAL       M         M          R
# ...             ...        ...           ...     ...       ...        ...
# 1147  LGNrevisedP40          R            v1       P         P          L
# 1148  LGNrevisedP40          R            v1       P         M          R
# 1149  LGNrevisedP40          R            v1       P         M          R
# 1150  LGNrevisedP40          R            v1       P         P          R
# 1151  LGNrevisedP40          R            v1       P         P          R
#
#       ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 880              True       True        1    0.400029   0.018575
# 881              True       True        2    0.346031   0.029811
# 882              True      False        1    0.391722   0.020266
# 883              True      False        2    0.345689   0.035987
# 884              True       True        1    0.355763   0.015826
# ...               ...        ...      ...         ...        ...
# 1147             True       True        2    0.370633   0.026141
# 1148             True      False        1    0.510418   0.075067
# 1149             True      False        2    0.368773   0.055301
# 1150             True       True        1    0.553691   0.028090
# 1151             True       True        2    0.400276   0.046685
#
# [272 rows x 17 columns]
#         subj            seed   target measurement condition seed_hem  \
# 1152  sub-ZG  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 1153  sub-ZG  LLGNrevisedM90  LDORSAL   coherence     leftM        L
# 1154  sub-ZG  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 1155  sub-ZG  LLGNrevisedM90  LDORSAL   coherence     leftP        L
# 1156  sub-ZG  LLGNrevisedM90  LDORSAL   coherence    rightM        L
# ...      ...             ...      ...         ...       ...      ...
# 1403  sub-ZG  RLGNrevisedP40      Rv1   coherence     leftP        R
# 1404  sub-ZG  RLGNrevisedP40      Rv1   coherence    rightM        R
# 1405  sub-ZG  RLGNrevisedP40      Rv1   coherence    rightM        R
# 1406  sub-ZG  RLGNrevisedP40      Rv1   coherence    rightP        R
# 1407  sub-ZG  RLGNrevisedP40      Rv1   coherence    rightP        R
#
#         seed_region target_hem target_region seed_mp stim_type attend_hem  \
# 1152  LGNrevisedM90          L        DORSAL       M         M          L
# 1153  LGNrevisedM90          L        DORSAL       M         M          L
# 1154  LGNrevisedM90          L        DORSAL       M         P          L
# 1155  LGNrevisedM90          L        DORSAL       M         P          L
# 1156  LGNrevisedM90          L        DORSAL       M         M          R
# ...             ...        ...           ...     ...       ...        ...
# 1403  LGNrevisedP40          R            v1       P         P          L
# 1404  LGNrevisedP40          R            v1       P         M          R
# 1405  LGNrevisedP40          R            v1       P         M          R
# 1406  LGNrevisedP40          R            v1       P         P          R
# 1407  LGNrevisedP40          R            v1       P         P          R
#
#       ipsi_seedtarget  seed_stim  session  value_mean  value_sem
# 1152             True       True        1    0.517386   0.100088
# 1153             True       True        2    0.319501   0.057580
# 1154             True      False        1    0.526228   0.021229
# 1155             True      False        2    0.474456   0.021799
# 1156             True       True        1    0.602528   0.083365
# ...               ...        ...      ...         ...        ...
# 1403             True       True        2    0.352960   0.004661
# 1404             True      False        1    0.508456   0.008271
# 1405             True      False        2    0.391639   0.022414
# 1406             True       True        1    0.423005   0.085917
# 1407             True       True        2    0.440207   0.020594
#
# [256 rows x 17 columns]

# %% [markdown]
# ## M-stim - P-stim contrasts (over different values of stim_type)

# %%
id_cols
# Out:
# ['subj', 'seed', 'target', 'measurement', 'condition']

# %%
constructed_cols
# Out:
# ['seed_hem',
#  'seed_region',
#  'target_hem',
#  'target_region',
#  'seed_mp',
#  'stim_type',
#  'attend_hem',
#  'ipsi_seedtarget',
#  'seed_stim']

# %%
df_meanrun.target_region.cat.categories
# Out:
# Index(['v1', 'V2', 'V3', 'V3AB', 'IPS', 'TO', 'V4', 'VO', 'LO', 'DORSAL',
#        'VENTRAL', 'v2d', 'v2v', 'v3d', 'v3v', 'v4', 'ips0', 'ips1', 'ips2',
#        'ips3', 'ips4', 'ips5', 'lo1', 'lo2', 'to1', 'to2', 'vo1', 'vo2'],
#       dtype='object')

# %%
mp_contrast_cols = ['subj', 'seed', 'target', 'measurement', 'seed_hem', 'seed_region', 
                   'target_hem','target_region','seed_mp', 'attend_hem', 'ipsi_seedtarget']
mp_xatt_cols = list(set(mp_contrast_cols).difference(['attend_hem']))
mp_xseed_cols = list(set(mp_contrast_cols).difference(['seed', 'seed_hem', 'seed_region', 'seed_mp']))

# %%
mp_xseed_cols
# Out:
# ['target_region',
#  'measurement',
#  'attend_hem',
#  'target_hem',
#  'ipsi_seedtarget',
#  'subj',
#  'target']

# %%
def mp_diff(df):
    #print(df)
    assert(len(df)==2)
    m = df[df.stim_type=='M']['value_mean']
    assert(len(m)==1)
    p = df[df.stim_type=='P']['value_mean']
    assert(len(p)==1)
    #print(m, p)
    diff = m.iloc[0] - p.iloc[0]
    #print(diff)
    return pd.Series({'mp_diff': diff})

def mp_seed_diff(df):
    #print(df)
    assert(len(df)==2)
    m = df[df.seed_mp=='M']['mp_mean']
    assert(len(m)==1)
    p = df[df.seed_mp=='P']['mp_mean']
    assert(len(p)==1)
    #print(m, p)
    diff = m.iloc[0] - p.iloc[0]
    #print(diff)
    return pd.Series({'mp_seed_diff': diff})

# %%
len(df_meanrun)
# Out:
# 1408

# %%
df_meanrun.groupby(mp_contrast_cols + ['session'], observed=True).describe()
# Out:
#                                                                                                                                       value_mean  \
#                                                                                                                                            count
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1              2.0
#                                                                                                                               2              2.0
#                                                                                                    R          True            1              2.0
#                                                                                                                               2              2.0
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1              2.0
# ...                                                                                                                                          ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2              2.0
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1              2.0
#                                                                                                                               2              2.0
#                                                                                                    R          True            1              2.0
#                                                                                                                               2              2.0
#
#                                                                                                                                                  \
#                                                                                                                                            mean
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.321924
#                                                                                                                               2        0.342533
#                                                                                                    R          True            1        0.414167
#                                                                                                                               2        0.430705
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.324880
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.428491
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.433363
#                                                                                                                               2        0.382940
#                                                                                                    R          True            1        0.465731
#                                                                                                                               2        0.415923
#
#                                                                                                                                                  \
#                                                                                                                                             std
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.044817
#                                                                                                                               2        0.017956
#                                                                                                    R          True            1        0.004578
#                                                                                                                               2        0.046439
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.023195
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.038694
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.018094
#                                                                                                                               2        0.042397
#                                                                                                    R          True            1        0.060423
#                                                                                                                               2        0.034343
#
#                                                                                                                                                  \
#                                                                                                                                             min
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.290234
#                                                                                                                               2        0.329836
#                                                                                                    R          True            1        0.410930
#                                                                                                                               2        0.397868
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.308479
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.401131
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.420569
#                                                                                                                               2        0.352960
#                                                                                                    R          True            1        0.423005
#                                                                                                                               2        0.391639
#
#                                                                                                                                                  \
#                                                                                                                                             25%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.306079
#                                                                                                                               2        0.336184
#                                                                                                    R          True            1        0.412548
#                                                                                                                               2        0.414287
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.316680
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.414811
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.426966
#                                                                                                                               2        0.367950
#                                                                                                    R          True            1        0.444368
#                                                                                                                               2        0.403781
#
#                                                                                                                                                  \
#                                                                                                                                             50%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.321924
#                                                                                                                               2        0.342533
#                                                                                                    R          True            1        0.414167
#                                                                                                                               2        0.430705
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.324880
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.428491
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.433363
#                                                                                                                               2        0.382940
#                                                                                                    R          True            1        0.465731
#                                                                                                                               2        0.415923
#
#                                                                                                                                                  \
#                                                                                                                                             75%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.337769
#                                                                                                                               2        0.348881
#                                                                                                    R          True            1        0.415785
#                                                                                                                               2        0.447124
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.333081
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.442172
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.439760
#                                                                                                                               2        0.397930
#                                                                                                    R          True            1        0.487094
#                                                                                                                               2        0.428065
#
#                                                                                                                                                  \
#                                                                                                                                             max
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.353614
#                                                                                                                               2        0.355229
#                                                                                                    R          True            1        0.417404
#                                                                                                                               2        0.463543
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.341282
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.455852
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.446157
#                                                                                                                               2        0.412919
#                                                                                                    R          True            1        0.508456
#                                                                                                                               2        0.440207
#
#                                                                                                                                       value_sem  \
#                                                                                                                                           count
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1             2.0
#                                                                                                                               2             2.0
#                                                                                                    R          True            1             2.0
#                                                                                                                               2             2.0
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1             2.0
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2             2.0
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1             2.0
#                                                                                                                               2             2.0
#                                                                                                    R          True            1             2.0
#                                                                                                                               2             2.0
#
#                                                                                                                                                  \
#                                                                                                                                            mean
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.037617
#                                                                                                                               2        0.020119
#                                                                                                    R          True            1        0.048211
#                                                                                                                               2        0.018753
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.043664
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.052145
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.057208
#                                                                                                                               2        0.011697
#                                                                                                    R          True            1        0.047094
#                                                                                                                               2        0.021504
#
#                                                                                                                                                  \
#                                                                                                                                             std
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.016788
#                                                                                                                               2        0.010261
#                                                                                                    R          True            1        0.016212
#                                                                                                                               2        0.011556
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.015169
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.016309
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.008643
#                                                                                                                               2        0.009951
#                                                                                                    R          True            1        0.054904
#                                                                                                                               2        0.001287
#
#                                                                                                                                                  \
#                                                                                                                                             min
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.025746
#                                                                                                                               2        0.012863
#                                                                                                    R          True            1        0.036747
#                                                                                                                               2        0.010581
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.032938
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.040613
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.051096
#                                                                                                                               2        0.004661
#                                                                                                    R          True            1        0.008271
#                                                                                                                               2        0.020594
#
#                                                                                                                                                  \
#                                                                                                                                             25%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.031682
#                                                                                                                               2        0.016491
#                                                                                                    R          True            1        0.042479
#                                                                                                                               2        0.014667
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.038301
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.046379
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.054152
#                                                                                                                               2        0.008179
#                                                                                                    R          True            1        0.027682
#                                                                                                                               2        0.021049
#
#                                                                                                                                                  \
#                                                                                                                                             50%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.037617
#                                                                                                                               2        0.020119
#                                                                                                    R          True            1        0.048211
#                                                                                                                               2        0.018753
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.043664
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.052145
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.057208
#                                                                                                                               2        0.011697
#                                                                                                    R          True            1        0.047094
#                                                                                                                               2        0.021504
#
#                                                                                                                                                  \
#                                                                                                                                             75%
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.043553
#                                                                                                                               2        0.023746
#                                                                                                    R          True            1        0.053943
#                                                                                                                               2        0.022838
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.049027
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.057911
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.060264
#                                                                                                                               2        0.015215
#                                                                                                    R          True            1        0.066505
#                                                                                                                               2        0.021959
#
#
#                                                                                                                                             max
# subj   seed           target   measurement seed_hem seed_region   target_hem target_region seed_mp attend_hem ipsi_seedtarget session
# sub-BC LLGNrevisedM90 LDORSAL  coherence   L        LGNrevisedM90 L          DORSAL        M       L          True            1        0.049488
#                                                                                                                               2        0.027374
#                                                                                                    R          True            1        0.059675
#                                                                                                                               2        0.026924
#                       LIPS     coherence   L        LGNrevisedM90 L          IPS           M       L          True            1        0.054390
# ...                                                                                                                                         ...
# sub-ZG RLGNrevisedP40 RVENTRAL coherence   R        LGNrevisedP40 R          VENTRAL       P       R          True            2        0.063677
#                       Rv1      coherence   R        LGNrevisedP40 R          v1            P       L          True            1        0.063320
#                                                                                                                               2        0.018733
#                                                                                                    R          True            1        0.085917
#                                                                                                                               2        0.022414
#
# [704 rows x 16 columns]

# %%
mp_groups = df_meanrun.groupby(mp_contrast_cols + ['session'], observed=True)
print(len(mp_groups))
mp_diffs = mp_groups.apply(mp_diff).reset_index()
# Out:
# 704

# %%
mp_diffs
# Out:
#        subj            seed    target measurement seed_hem    seed_region  \
# 0    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 1    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 2    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 3    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 4    sub-BC  LLGNrevisedM90      LIPS   coherence        L  LGNrevisedM90
# ..      ...             ...       ...         ...      ...            ...
# 699  sub-ZG  RLGNrevisedP40  RVENTRAL   coherence        R  LGNrevisedP40
# 700  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
# 701  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
# 702  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
# 703  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
#
#     target_hem target_region seed_mp attend_hem  ipsi_seedtarget  session  \
# 0            L        DORSAL       M          L             True        1
# 1            L        DORSAL       M          L             True        2
# 2            L        DORSAL       M          R             True        1
# 3            L        DORSAL       M          R             True        2
# 4            L           IPS       M          L             True        1
# ..         ...           ...     ...        ...              ...      ...
# 699          R       VENTRAL       P          R             True        2
# 700          R            v1       P          L             True        1
# 701          R            v1       P          L             True        2
# 702          R            v1       P          R             True        1
# 703          R            v1       P          R             True        2
#
#       mp_diff
# 0    0.063380
# 1    0.025393
# 2   -0.006474
# 3    0.065675
# 4    0.032803
# ..        ...
# 699 -0.054721
# 700 -0.025588
# 701  0.059959
# 702  0.085451
# 703 -0.048568
#
# [704 rows x 13 columns]

# %%
mp_diffs.groupby(mp_contrast_cols, observed=True)['mp_diff'].mean().reset_index()
# Out:
#        subj            seed    target measurement seed_hem    seed_region  \
# 0    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 1    sub-BC  LLGNrevisedM90   LDORSAL   coherence        L  LGNrevisedM90
# 2    sub-BC  LLGNrevisedM90      LIPS   coherence        L  LGNrevisedM90
# 3    sub-BC  LLGNrevisedM90      LIPS   coherence        L  LGNrevisedM90
# 4    sub-BC  LLGNrevisedM90       LLO   coherence        L  LGNrevisedM90
# ..      ...             ...       ...         ...      ...            ...
# 347  sub-ZG  RLGNrevisedP40     RV3AB   coherence        R  LGNrevisedP40
# 348  sub-ZG  RLGNrevisedP40  RVENTRAL   coherence        R  LGNrevisedP40
# 349  sub-ZG  RLGNrevisedP40  RVENTRAL   coherence        R  LGNrevisedP40
# 350  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
# 351  sub-ZG  RLGNrevisedP40       Rv1   coherence        R  LGNrevisedP40
#
#     target_hem target_region seed_mp attend_hem  ipsi_seedtarget   mp_diff
# 0            L        DORSAL       M          L             True  0.044387
# 1            L        DORSAL       M          R             True  0.029601
# 2            L           IPS       M          L             True  0.053444
# 3            L           IPS       M          R             True  0.019283
# 4            L            LO       M          L             True  0.042373
# ..         ...           ...     ...        ...              ...       ...
# 347          R          V3AB       P          R             True  0.057399
# 348          R       VENTRAL       P          L             True -0.005543
# 349          R       VENTRAL       P          R             True  0.002174
# 350          R            v1       P          L             True  0.017185
# 351          R            v1       P          R             True  0.018442
#
# [352 rows x 12 columns]

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    for gv, g in mp_diffs.groupby(['subj']):
        #print(g)
        sns.catplot(data=g.reset_index(), kind='strip', x='target_region', y='mp_diff', row='seed_mp',
                    col='target_hem', hue='session', sharex=False, legend=True, ci=None, dodge=True,
                    order=display_order) \
        .set_axis_labels('Target', "M-P (stimulation) difference in \nLGN subregion coherence with ipsilateral cortical targets") \
        .fig.suptitle(f"{gv} LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
mp_df = mp_diffs.groupby(mp_contrast_cols, observed=True)['mp_diff'].agg(['mean', 'sem'])
mp_df.columns = mp_df.columns.map(lambda x: f"mp_{x}")
mp_df = mp_df.reset_index()
mp_df_reduced = mp_df[mp_df.target_region.isin(display_regions)].copy()
mp_df_reduced.head()
# Out:
#      subj            seed   target measurement seed_hem    seed_region  \
# 0  sub-BC  LLGNrevisedM90  LDORSAL   coherence        L  LGNrevisedM90
# 1  sub-BC  LLGNrevisedM90  LDORSAL   coherence        L  LGNrevisedM90
# 2  sub-BC  LLGNrevisedM90     LIPS   coherence        L  LGNrevisedM90
# 3  sub-BC  LLGNrevisedM90     LIPS   coherence        L  LGNrevisedM90
# 4  sub-BC  LLGNrevisedM90      LLO   coherence        L  LGNrevisedM90
#
#   target_hem target_region seed_mp attend_hem  ipsi_seedtarget   mp_mean  \
# 0          L        DORSAL       M          L             True  0.044387
# 1          L        DORSAL       M          R             True  0.029601
# 2          L           IPS       M          L             True  0.053444
# 3          L           IPS       M          R             True  0.019283
# 4          L            LO       M          L             True  0.042373
#
#      mp_sem
# 0  0.018993
# 1  0.036074
# 2  0.020642
# 3  0.042441
# 4  0.110244

# %%
plot_df = mp_df_reduced
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    g = sns.catplot(data=plot_df, kind='strip', x='target_region', y='mp_mean', hue='subj', col='seed_mp',
                    sharex=False, legend=True, ci=None, order=display_order, row='attend_hem')
    g.set_axis_labels('Target', "M-P Coherence difference") \
    .fig.suptitle("M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
mp_df_xatt = mp_df_reduced.groupby(mp_xatt_cols, observed=True)['mp_mean'].mean().reset_index()
plot_df = mp_df_xatt
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    g = sns.catplot(data=plot_df, kind='strip', x='target_region', y='mp_mean', hue='seed_region',
                    col='target_hem', sharex=False, legend=True, ci=None, order=display_order) \
        .set_axis_labels('Target', "M-P Coherence difference") \
.fig.suptitle("M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
plot_df = mp_df_xatt
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    g = sns.catplot(data=plot_df, kind='strip', x='target_region', y='mp_mean', hue='subj', row="seed_region",
                    col='target_hem', sharex=False, legend=True, ci=None, order=display_order) \
        .set_axis_labels('Target', "M-P Coherence difference") \
.fig.suptitle("M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
mp_xatt_xhem_df = mp_df_xatt.groupby(
   ['subj','target_region','seed_mp','seed_region'], observed=True)['mp_mean'].mean().reset_index()
plot_df = mp_xatt_xhem_df
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    g = sns.catplot(data=plot_df, kind='strip', x='target_region', y='mp_mean', hue='subj', col='seed_region',
                    sharex=False, legend=True, ci=None, order=display_order) \
            .set_axis_labels('Target', "M-P Coherence difference") \
            .fig.suptitle("M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets", y=1.03)

# %%
ax = sns.barplot(data=mp_xatt_xhem_df, x='target_region', y='mp_mean', hue="seed_mp", errorbar="se", order=display_order)
ax.set(xlabel='Target', ylabel="M-P Coherence difference")
ax.title.set_text("M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets")
ax = sns.swarmplot(data=mp_xatt_xhem_df, x='target_region', y='mp_mean', hue="seed_mp", ax=ax, dodge=True,
                   palette='dark:#555555', legend=False)

# %%
mp_xseed_groups = mp_df_reduced.groupby(mp_xseed_cols, observed=True)
mp_xseed_diffs = mp_xseed_groups.apply(mp_seed_diff).reset_index()

# %%
mp_xatt_xseed_df = mp_xseed_diffs.groupby(
    list(set(mp_xseed_cols).difference(['attend_hem'])), observed=True)['mp_seed_diff'].mean().reset_index()
mp_xatt_xseed_xhem_df = mp_xatt_xseed_df

# %%
mp_xseed_cols
# Out:
# ['target_region',
#  'measurement',
#  'attend_hem',
#  'target_hem',
#  'ipsi_seedtarget',
#  'subj',
#  'target']

# %%
mp_xatt_xseed_xhem_df = mp_xatt_xseed_df.groupby(
    ['subj','target_region'], observed=True)['mp_seed_diff'].mean().reset_index()

# %%
mp_xatt_xseed_xhem_df
# Out:
#       subj target_region  mp_seed_diff
# 0   sub-BC            v1      0.002970
# 1   sub-BC            V2      0.029391
# 2   sub-BC            V3     -0.043567
# 3   sub-BC          V3AB      0.009417
# 4   sub-BC           IPS      0.036637
# 5   sub-BC            TO      0.003689
# 6   sub-BC            V4      0.015747
# 7   sub-BC            VO      0.015747
# 8   sub-BC            LO      0.007529
# 9   sub-BC        DORSAL      0.024872
# 10  sub-BC       VENTRAL      0.010210
# 11  sub-CF            v1      0.003521
# 12  sub-CF            V2     -0.003067
# 13  sub-CF            V3     -0.005488
# 14  sub-CF          V3AB     -0.005946
# 15  sub-CF           IPS      0.038641
# 16  sub-CF        DORSAL     -0.002805
# 17  sub-LL            v1     -0.002005
# 18  sub-LL            V2      0.005198
# 19  sub-LL            V3      0.042968
# 20  sub-LL          V3AB      0.016839
# 21  sub-LL           IPS     -0.020959
# 22  sub-LL            TO      0.019878
# 23  sub-LL            V4      0.027857
# 24  sub-LL            VO      0.002894
# 25  sub-LL            LO      0.039953
# 26  sub-LL        DORSAL     -0.002048
# 27  sub-LL       VENTRAL      0.034743
# 28  sub-SR            v1     -0.015883
# 29  sub-SR            V2     -0.005736
# 30  sub-SR            V3     -0.001259
# 31  sub-SR          V3AB      0.009799
# 32  sub-SR           IPS     -0.010402
# 33  sub-SR            TO     -0.023562
# 34  sub-SR            LO     -0.046997
# 35  sub-SR        DORSAL     -0.004275
# 36  sub-SR       VENTRAL     -0.046997
# 37  sub-ZG            v1     -0.031280
# 38  sub-ZG            V2     -0.044170
# 39  sub-ZG            V3     -0.031182
# 40  sub-ZG          V3AB     -0.041674
# 41  sub-ZG           IPS     -0.032993
# 42  sub-ZG            LO     -0.021056
# 43  sub-ZG        DORSAL     -0.037575
# 44  sub-ZG       VENTRAL     -0.021056

# %%
plot_df = mp_xatt_xseed_xhem_df
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    g = sns.catplot(data=plot_df, kind='strip', x='target_region', y='mp_seed_diff', hue='subj',
                    sharex=False, legend=True, ci=None, order=display_order)
    g.set_axis_labels('Target', "M-P Coherence difference") \
            .fig.suptitle("Difference (M-seed - P-seed) of\n(M-P (stimulation) difference in LGN subregion coherence with ipsilateral cortical targets)", y=1.03)
    g.ax.axhline(y=0, linestyle='dotted', color='black')

# %%
mp_final_mean = mp_xatt_xseed_xhem_df.groupby(['subj']).mean().reset_index()
mp_final_mean['target_region'] = 'mean'
mp_plot_df = pd.concat((mp_xatt_xseed_xhem_df, mp_final_mean)).reset_index()
mp_plot_df
# Out:
# /tmp/ipykernel_252284/4221948660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mp_final_mean = mp_xatt_xseed_xhem_df.groupby(['subj']).mean().reset_index()
#     index    subj target_region  mp_seed_diff
# 0       0  sub-BC            v1      0.002970
# 1       1  sub-BC            V2      0.029391
# 2       2  sub-BC            V3     -0.043567
# 3       3  sub-BC          V3AB      0.009417
# 4       4  sub-BC           IPS      0.036637
# 5       5  sub-BC            TO      0.003689
# 6       6  sub-BC            V4      0.015747
# 7       7  sub-BC            VO      0.015747
# 8       8  sub-BC            LO      0.007529
# 9       9  sub-BC        DORSAL      0.024872
# 10     10  sub-BC       VENTRAL      0.010210
# 11     11  sub-CF            v1      0.003521
# 12     12  sub-CF            V2     -0.003067
# 13     13  sub-CF            V3     -0.005488
# 14     14  sub-CF          V3AB     -0.005946
# 15     15  sub-CF           IPS      0.038641
# 16     16  sub-CF        DORSAL     -0.002805
# 17     17  sub-LL            v1     -0.002005
# 18     18  sub-LL            V2      0.005198
# 19     19  sub-LL            V3      0.042968
# 20     20  sub-LL          V3AB      0.016839
# 21     21  sub-LL           IPS     -0.020959
# 22     22  sub-LL            TO      0.019878
# 23     23  sub-LL            V4      0.027857
# 24     24  sub-LL            VO      0.002894
# 25     25  sub-LL            LO      0.039953
# 26     26  sub-LL        DORSAL     -0.002048
# 27     27  sub-LL       VENTRAL      0.034743
# 28     28  sub-SR            v1     -0.015883
# 29     29  sub-SR            V2     -0.005736
# 30     30  sub-SR            V3     -0.001259
# 31     31  sub-SR          V3AB      0.009799
# 32     32  sub-SR           IPS     -0.010402
# 33     33  sub-SR            TO     -0.023562
# 34     34  sub-SR            LO     -0.046997
# 35     35  sub-SR        DORSAL     -0.004275
# 36     36  sub-SR       VENTRAL     -0.046997
# 37     37  sub-ZG            v1     -0.031280
# 38     38  sub-ZG            V2     -0.044170
# 39     39  sub-ZG            V3     -0.031182
# 40     40  sub-ZG          V3AB     -0.041674
# 41     41  sub-ZG           IPS     -0.032993
# 42     42  sub-ZG            LO     -0.021056
# 43     43  sub-ZG        DORSAL     -0.037575
# 44     44  sub-ZG       VENTRAL     -0.021056
# 45      0  sub-BC          mean      0.010240
# 46      1  sub-CF          mean      0.004143
# 47      2  sub-LL          mean      0.015029
# 48      3  sub-SR          mean     -0.016146
# 49      4  sub-ZG          mean     -0.032623

# %%
def tt(df, col='mp_seed_diff'):
    print(st.ttest_1samp(df[col], popmean=0))

for gv, g in mp_plot_df.groupby(['target_region'], observed=True):
    print(gv, tt(g))
# Out:
# Ttest_1sampResult(statistic=-0.440438375495869, pvalue=0.6823748302908357)
# DORSAL None
# Ttest_1sampResult(statistic=0.14649668297201834, pvalue=0.8906159870315966)
# IPS None
# Ttest_1sampResult(statistic=-0.2749097916740131, pvalue=0.8012312031569333)
# LO None
# Ttest_1sampResult(statistic=0.00013427545385008018, pvalue=0.9999050529164637)
# TO None
# Ttest_1sampResult(statistic=-0.3098399540232679, pvalue=0.7721534872777587)
# V2 None
# Ttest_1sampResult(statistic=-0.5165046282308448, pvalue=0.632744306213757)
# V3 None
# Ttest_1sampResult(statistic=-0.21987110368217072, pvalue=0.8367366929564155)
# V3AB None
# Ttest_1sampResult(statistic=3.6007438809661036, pvalue=0.1724562053879748)
# V4 None
# Ttest_1sampResult(statistic=-0.3232590142516127, pvalue=0.7677212757548523)
# VENTRAL None
# Ttest_1sampResult(statistic=1.4502294946703642, pvalue=0.38431167691711143)
# VO None
# Ttest_1sampResult(statistic=-0.4331298985612734, pvalue=0.6872534849933611)
# mean None
# Ttest_1sampResult(statistic=-1.278324100201102, pvalue=0.2702715806898125)
# v1 None
# /tmp/ipykernel_252284/3579368815.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for gv, g in mp_plot_df.groupby(['target_region'], observed=True):

# %%
mp_plot_df.to_csv('mp_plot_df_4010_volconstraint.csv')

# %%
mp_disp = display_order + ['mean']
fig, ax = plt.subplots(1, 1, figsize=(10, 4))
ax = sns.barplot(data=mp_plot_df, x='target_region', y='mp_seed_diff', errorbar="se",
                 order=mp_disp, color="#888888", ax=ax)
ax.set(xlabel='Target', ylabel="Difference of coherences\n(Compatible - Incompatible)")
ax.title.set_text("Difference (Compatible - Incompatible) of\nLGN subregion coherence with ipsilateral cortical targets")
ax = sns.swarmplot(data=mp_plot_df, x='target_region', y='mp_seed_diff', ax=ax, dodge=True, order=mp_disp,
                   color="#555555", legend=False)

# %%
# ax = sns.barplot(data=mp_xatt_xseed_xhem_df, x='target_region', y='mp_seed_diff', errorbar="se",
#                  order=display_order, color="#888888")
# ax.set(xlabel='Target', ylabel="Difference of coherences\n(Compatible - Incompatible stimulation)")
# ax.title.set_text("Difference (Compatible - Incompatible stimulus) of\nLGN subregion coherence with ipsilateral cortical targets")
# ax = sns.swarmplot(data=mp_xatt_xseed_xhem_df, x='target_region', y='mp_seed_diff', ax=ax, dodge=True,
#                    color="#555555", legend=False)
